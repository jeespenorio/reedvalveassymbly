# %%
#import libraries

import os
import numpy as np
import pandas as pd
import psycopg2

# %%
path = r"C:\Users\User\Desktop\nachmann\Reed Valve Assemblies\Automatic_Distributors_Reed_Valve_Assemblies.csv"
df = pd.read_csv(path)
df.head(10)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['SKI-DOO'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['07-102-08'], 'AD Item Number': ['121284'], 
         'Vendor Notes': [pd.NA], 'NI#': ['07-102-08'], 'REF#': [pd.NA], 'OEM#': ['420867879']}

# List of models
new_list_models = [
'MX Z X-RS E-TEC 600 HO',
'MX Z X E-TEC 600 HO',
'MX Z TNT E-TEC 600 HO',
'MX Z Blizzard E-TEC 600 HO',
'MX Z X-RS Iron Dog E-TEC 600 HO',
'MX Z 600 Trail',
'MX Z 600 X',
'MX Z 600 Sport',
'MX Z 600 Renegade',
'MX Z 600 Adrenaline'
]

oem_numbers = ['420867879']

# Range of years
years = list(range(2003, 2004))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)
# Out:
#       Make                            Model Vendor        MPN AD Item Number  \
# 0  SKI-DOO           MX Z X-RS E-TEC 600 HO   NACH  07-102-08         121284
# 1  SKI-DOO              MX Z X E-TEC 600 HO   NACH  07-102-08         121284
# 2  SKI-DOO            MX Z TNT E-TEC 600 HO   NACH  07-102-08         121284
# 3  SKI-DOO       MX Z Blizzard E-TEC 600 HO   NACH  07-102-08         121284
# 4  SKI-DOO  MX Z X-RS Iron Dog E-TEC 600 HO   NACH  07-102-08         121284
# 5  SKI-DOO                   MX Z 600 Trail   NACH  07-102-08         121284
# 6  SKI-DOO                       MX Z 600 X   NACH  07-102-08         121284
# 7  SKI-DOO                   MX Z 600 Sport   NACH  07-102-08         121284
# 8  SKI-DOO                MX Z 600 Renegade   NACH  07-102-08         121284
# 9  SKI-DOO              MX Z 600 Adrenaline   NACH  07-102-08         121284
#
#   Vendor Notes        NI#  REF#       OEM#  Year
# 0         <NA>  07-102-08  <NA>  420867879  2003
# 1         <NA>  07-102-08  <NA>  420867879  2003
# 2         <NA>  07-102-08  <NA>  420867879  2003
# 3         <NA>  07-102-08  <NA>  420867879  2003
# 4         <NA>  07-102-08  <NA>  420867879  2003
# 5         <NA>  07-102-08  <NA>  420867879  2003
# 6         <NA>  07-102-08  <NA>  420867879  2003
# 7         <NA>  07-102-08  <NA>  420867879  2003
# 8         <NA>  07-102-08  <NA>  420867879  2003
# 9         <NA>  07-102-08  <NA>  420867879  2003

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Reed Valve Assemblies\MERGE\2003.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['SKI-DOO'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['07-102-08'], 'AD Item Number': ['121284'], 
         'Vendor Notes': [pd.NA], 'NI#': ['07-102-08'], 'REF#': [pd.NA], 'OEM#': ['420867879']}

# List of models
new_list_models = [
'GSX 600',
'GSX 600 Limited',
'GSX 600 Sport',
'GSX 600 Sport SDI'
]

oem_numbers = ['420867879']

# Range of years
years = list(range(2004, 2006))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)
# Out:
#       Make              Model Vendor        MPN AD Item Number Vendor Notes  \
# 0  SKI-DOO            GSX 600   NACH  07-102-08         121284         <NA>
# 1  SKI-DOO    GSX 600 Limited   NACH  07-102-08         121284         <NA>
# 2  SKI-DOO      GSX 600 Sport   NACH  07-102-08         121284         <NA>
# 3  SKI-DOO  GSX 600 Sport SDI   NACH  07-102-08         121284         <NA>
# 4  SKI-DOO            GSX 600   NACH  07-102-08         121284         <NA>
# 5  SKI-DOO    GSX 600 Limited   NACH  07-102-08         121284         <NA>
# 6  SKI-DOO      GSX 600 Sport   NACH  07-102-08         121284         <NA>
# 7  SKI-DOO  GSX 600 Sport SDI   NACH  07-102-08         121284         <NA>
#
#          NI#  REF#       OEM#  Year
# 0  07-102-08  <NA>  420867879  2004
# 1  07-102-08  <NA>  420867879  2004
# 2  07-102-08  <NA>  420867879  2004
# 3  07-102-08  <NA>  420867879  2004
# 4  07-102-08  <NA>  420867879  2005
# 5  07-102-08  <NA>  420867879  2005
# 6  07-102-08  <NA>  420867879  2005
# 7  07-102-08  <NA>  420867879  2005

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Reed Valve Assemblies\MERGE\04-05.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['SKI-DOO'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['07-102-08'], 'AD Item Number': ['121284'], 
         'Vendor Notes': [pd.NA], 'NI#': ['07-102-08'], 'REF#': [pd.NA], 'OEM#': ['420867879']}

# List of models
new_list_models = [
'MX Z 600 Renegade X',
'MX Z 600 X',
'MX Z X-RS E-TEC 600 HO',
'MX Z X E-TEC 600 HO',
'MX Z TNT E-TEC 600 HO',
'MX Z Blizzard E-TEC 600 HO',
'MX Z X-RS Iron Dog E-TEC 600 HO',
'MX Z 600 Trail',
'MX Z 600 Sport',
'MX Z 600 Renegade',
'MX Z 600 Adrenaline',
'MX Z X-RS 600',
'MX Z X E-TEC 600R',
'MX Z X-RS E-TEC 600R',
'MX Z 600 X-RS',
'MX Z 600 R X'
]

oem_numbers = ['420867879']

# Range of years
years = list(range(2004, 2006))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)
# Out:
#        Make                            Model Vendor        MPN AD Item Number  \
# 0   SKI-DOO              MX Z 600 Renegade X   NACH  07-102-08         121284
# 1   SKI-DOO                       MX Z 600 X   NACH  07-102-08         121284
# 2   SKI-DOO           MX Z X-RS E-TEC 600 HO   NACH  07-102-08         121284
# 3   SKI-DOO              MX Z X E-TEC 600 HO   NACH  07-102-08         121284
# 4   SKI-DOO            MX Z TNT E-TEC 600 HO   NACH  07-102-08         121284
# 5   SKI-DOO       MX Z Blizzard E-TEC 600 HO   NACH  07-102-08         121284
# 6   SKI-DOO  MX Z X-RS Iron Dog E-TEC 600 HO   NACH  07-102-08         121284
# 7   SKI-DOO                   MX Z 600 Trail   NACH  07-102-08         121284
# 8   SKI-DOO                   MX Z 600 Sport   NACH  07-102-08         121284
# 9   SKI-DOO                MX Z 600 Renegade   NACH  07-102-08         121284
# 10  SKI-DOO              MX Z 600 Adrenaline   NACH  07-102-08         121284
# 11  SKI-DOO                    MX Z X-RS 600   NACH  07-102-08         121284
# 12  SKI-DOO                MX Z X E-TEC 600R   NACH  07-102-08         121284
# 13  SKI-DOO             MX Z X-RS E-TEC 600R   NACH  07-102-08         121284
# 14  SKI-DOO                    MX Z 600 X-RS   NACH  07-102-08         121284
# 15  SKI-DOO                     MX Z 600 R X   NACH  07-102-08         121284
# 16  SKI-DOO              MX Z 600 Renegade X   NACH  07-102-08         121284
# 17  SKI-DOO                       MX Z 600 X   NACH  07-102-08         121284
# 18  SKI-DOO           MX Z X-RS E-TEC 600 HO   NACH  07-102-08         121284
# 19  SKI-DOO              MX Z X E-TEC 600 HO   NACH  07-102-08         121284
# 20  SKI-DOO            MX Z TNT E-TEC 600 HO   NACH  07-102-08         121284
# 21  SKI-DOO       MX Z Blizzard E-TEC 600 HO   NACH  07-102-08         121284
# 22  SKI-DOO  MX Z X-RS Iron Dog E-TEC 600 HO   NACH  07-102-08         121284
# 23  SKI-DOO                   MX Z 600 Trail   NACH  07-102-08         121284
# 24  SKI-DOO                   MX Z 600 Sport   NACH  07-102-08         121284
# 25  SKI-DOO                MX Z 600 Renegade   NACH  07-102-08         121284
# 26  SKI-DOO              MX Z 600 Adrenaline   NACH  07-102-08         121284
# 27  SKI-DOO                    MX Z X-RS 600   NACH  07-102-08         121284
# 28  SKI-DOO                MX Z X E-TEC 600R   NACH  07-102-08         121284
# 29  SKI-DOO             MX Z X-RS E-TEC 600R   NACH  07-102-08         121284
# 30  SKI-DOO                    MX Z 600 X-RS   NACH  07-102-08         121284
# 31  SKI-DOO                     MX Z 600 R X   NACH  07-102-08         121284
#
#    Vendor Notes        NI#  REF#       OEM#  Year
# 0          <NA>  07-102-08  <NA>  420867879  2004
# 1          <NA>  07-102-08  <NA>  420867879  2004
# 2          <NA>  07-102-08  <NA>  420867879  2004
# 3          <NA>  07-102-08  <NA>  420867879  2004
# 4          <NA>  07-102-08  <NA>  420867879  2004
# 5          <NA>  07-102-08  <NA>  420867879  2004
# 6          <NA>  07-102-08  <NA>  420867879  2004
# 7          <NA>  07-102-08  <NA>  420867879  2004
# 8          <NA>  07-102-08  <NA>  420867879  2004
# 9          <NA>  07-102-08  <NA>  420867879  2004
# 10         <NA>  07-102-08  <NA>  420867879  2004
# 11         <NA>  07-102-08  <NA>  420867879  2004
# 12         <NA>  07-102-08  <NA>  420867879  2004
# 13         <NA>  07-102-08  <NA>  420867879  2004
# 14         <NA>  07-102-08  <NA>  420867879  2004
# 15         <NA>  07-102-08  <NA>  420867879  2004
# 16         <NA>  07-102-08  <NA>  420867879  2005
# 17         <NA>  07-102-08  <NA>  420867879  2005
# 18         <NA>  07-102-08  <NA>  420867879  2005
# 19         <NA>  07-102-08  <NA>  420867879  2005
# 20         <NA>  07-102-08  <NA>  420867879  2005
# 21         <NA>  07-102-08  <NA>  420867879  2005
# 22         <NA>  07-102-08  <NA>  420867879  2005
# 23         <NA>  07-102-08  <NA>  420867879  2005
# 24         <NA>  07-102-08  <NA>  420867879  2005
# 25         <NA>  07-102-08  <NA>  420867879  2005
# 26         <NA>  07-102-08  <NA>  420867879  2005
# 27         <NA>  07-102-08  <NA>  420867879  2005
# 28         <NA>  07-102-08  <NA>  420867879  2005
# 29         <NA>  07-102-08  <NA>  420867879  2005
# 30         <NA>  07-102-08  <NA>  420867879  2005
# 31         <NA>  07-102-08  <NA>  420867879  2005

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Reed Valve Assemblies\MERGE\04-05mx z 600.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['SKI-DOO'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['07-102-08'], 'AD Item Number': ['121284'], 
         'Vendor Notes': [pd.NA], 'NI#': ['07-102-08'], 'REF#': [pd.NA], 'OEM#': ['420867879']}

# List of models
new_list_models = [
'Summit 600 Adrenaline',
'Summit 600 X',
'Summit 600 Adrenaline'
]

oem_numbers = ['420867879']

# Range of years
years = list(range(2004, 2006))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)
# Out:
#       Make                  Model Vendor        MPN AD Item Number  \
# 0  SKI-DOO  Summit 600 Adrenaline   NACH  07-102-08         121284
# 1  SKI-DOO           Summit 600 X   NACH  07-102-08         121284
# 2  SKI-DOO  Summit 600 Adrenaline   NACH  07-102-08         121284
# 3  SKI-DOO  Summit 600 Adrenaline   NACH  07-102-08         121284
# 4  SKI-DOO           Summit 600 X   NACH  07-102-08         121284
# 5  SKI-DOO  Summit 600 Adrenaline   NACH  07-102-08         121284
#
#   Vendor Notes        NI#  REF#       OEM#  Year
# 0         <NA>  07-102-08  <NA>  420867879  2004
# 1         <NA>  07-102-08  <NA>  420867879  2004
# 2         <NA>  07-102-08  <NA>  420867879  2004
# 3         <NA>  07-102-08  <NA>  420867879  2005
# 4         <NA>  07-102-08  <NA>  420867879  2005
# 5         <NA>  07-102-08  <NA>  420867879  2005

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Reed Valve Assemblies\MERGE\04-05SUMMIT600.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['SKI-DOO'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['07-102-08'], 'AD Item Number': ['121284'], 
         'Vendor Notes': [pd.NA], 'NI#': ['07-102-08'], 'REF#': [pd.NA], 'OEM#': ['420867879']}

# List of models
new_list_models = [
'MX Z 600 Renegade',
'MX Z 600 Adrenaline',
'MX Z 600 X',
'MX Z 600 Trail',
'MX Z 600 Renegade X'
]

oem_numbers = ['420867879']

# Range of years
years = list(range(2004, 2008))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)
# Out:
#        Make                Model Vendor        MPN AD Item Number  \
# 0   SKI-DOO    MX Z 600 Renegade   NACH  07-102-08         121284
# 1   SKI-DOO  MX Z 600 Adrenaline   NACH  07-102-08         121284
# 2   SKI-DOO           MX Z 600 X   NACH  07-102-08         121284
# 3   SKI-DOO       MX Z 600 Trail   NACH  07-102-08         121284
# 4   SKI-DOO  MX Z 600 Renegade X   NACH  07-102-08         121284
# 5   SKI-DOO    MX Z 600 Renegade   NACH  07-102-08         121284
# 6   SKI-DOO  MX Z 600 Adrenaline   NACH  07-102-08         121284
# 7   SKI-DOO           MX Z 600 X   NACH  07-102-08         121284
# 8   SKI-DOO       MX Z 600 Trail   NACH  07-102-08         121284
# 9   SKI-DOO  MX Z 600 Renegade X   NACH  07-102-08         121284
# 10  SKI-DOO    MX Z 600 Renegade   NACH  07-102-08         121284
# 11  SKI-DOO  MX Z 600 Adrenaline   NACH  07-102-08         121284
# 12  SKI-DOO           MX Z 600 X   NACH  07-102-08         121284
# 13  SKI-DOO       MX Z 600 Trail   NACH  07-102-08         121284
# 14  SKI-DOO  MX Z 600 Renegade X   NACH  07-102-08         121284
# 15  SKI-DOO    MX Z 600 Renegade   NACH  07-102-08         121284
# 16  SKI-DOO  MX Z 600 Adrenaline   NACH  07-102-08         121284
# 17  SKI-DOO           MX Z 600 X   NACH  07-102-08         121284
# 18  SKI-DOO       MX Z 600 Trail   NACH  07-102-08         121284
# 19  SKI-DOO  MX Z 600 Renegade X   NACH  07-102-08         121284
#
#    Vendor Notes        NI#  REF#       OEM#  Year
# 0          <NA>  07-102-08  <NA>  420867879  2004
# 1          <NA>  07-102-08  <NA>  420867879  2004
# 2          <NA>  07-102-08  <NA>  420867879  2004
# 3          <NA>  07-102-08  <NA>  420867879  2004
# 4          <NA>  07-102-08  <NA>  420867879  2004
# 5          <NA>  07-102-08  <NA>  420867879  2005
# 6          <NA>  07-102-08  <NA>  420867879  2005
# 7          <NA>  07-102-08  <NA>  420867879  2005
# 8          <NA>  07-102-08  <NA>  420867879  2005
# 9          <NA>  07-102-08  <NA>  420867879  2005
# 10         <NA>  07-102-08  <NA>  420867879  2006
# 11         <NA>  07-102-08  <NA>  420867879  2006
# 12         <NA>  07-102-08  <NA>  420867879  2006
# 13         <NA>  07-102-08  <NA>  420867879  2006
# 14         <NA>  07-102-08  <NA>  420867879  2006
# 15         <NA>  07-102-08  <NA>  420867879  2007
# 16         <NA>  07-102-08  <NA>  420867879  2007
# 17         <NA>  07-102-08  <NA>  420867879  2007
# 18         <NA>  07-102-08  <NA>  420867879  2007
# 19         <NA>  07-102-08  <NA>  420867879  2007

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Reed Valve Assemblies\MERGE\04-05600HO.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['SKI-DOO'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['07-102-08'], 'AD Item Number': ['121284'], 
         'Vendor Notes': [pd.NA], 'NI#': ['07-102-08'], 'REF#': [pd.NA], 'OEM#': ['420867879']}

# List of models
new_list_models = [
'MX Z 600 Renegade',
'MX Z 600 Adrenaline',
'MX Z 600 X',
'MX Z 600 Trail',
'MX Z 600 Renegade X'
]

oem_numbers = ['420867879']

# Range of years
years = list(range(2004, 2008))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)
# Out:
#        Make                Model Vendor        MPN AD Item Number  \
# 0   SKI-DOO    MX Z 600 Renegade   NACH  07-102-08         121284
# 1   SKI-DOO  MX Z 600 Adrenaline   NACH  07-102-08         121284
# 2   SKI-DOO           MX Z 600 X   NACH  07-102-08         121284
# 3   SKI-DOO       MX Z 600 Trail   NACH  07-102-08         121284
# 4   SKI-DOO  MX Z 600 Renegade X   NACH  07-102-08         121284
# 5   SKI-DOO    MX Z 600 Renegade   NACH  07-102-08         121284
# 6   SKI-DOO  MX Z 600 Adrenaline   NACH  07-102-08         121284
# 7   SKI-DOO           MX Z 600 X   NACH  07-102-08         121284
# 8   SKI-DOO       MX Z 600 Trail   NACH  07-102-08         121284
# 9   SKI-DOO  MX Z 600 Renegade X   NACH  07-102-08         121284
# 10  SKI-DOO    MX Z 600 Renegade   NACH  07-102-08         121284
# 11  SKI-DOO  MX Z 600 Adrenaline   NACH  07-102-08         121284
# 12  SKI-DOO           MX Z 600 X   NACH  07-102-08         121284
# 13  SKI-DOO       MX Z 600 Trail   NACH  07-102-08         121284
# 14  SKI-DOO  MX Z 600 Renegade X   NACH  07-102-08         121284
# 15  SKI-DOO    MX Z 600 Renegade   NACH  07-102-08         121284
# 16  SKI-DOO  MX Z 600 Adrenaline   NACH  07-102-08         121284
# 17  SKI-DOO           MX Z 600 X   NACH  07-102-08         121284
# 18  SKI-DOO       MX Z 600 Trail   NACH  07-102-08         121284
# 19  SKI-DOO  MX Z 600 Renegade X   NACH  07-102-08         121284
#
#    Vendor Notes        NI#  REF#       OEM#  Year
# 0          <NA>  07-102-08  <NA>  420867879  2004
# 1          <NA>  07-102-08  <NA>  420867879  2004
# 2          <NA>  07-102-08  <NA>  420867879  2004
# 3          <NA>  07-102-08  <NA>  420867879  2004
# 4          <NA>  07-102-08  <NA>  420867879  2004
# 5          <NA>  07-102-08  <NA>  420867879  2005
# 6          <NA>  07-102-08  <NA>  420867879  2005
# 7          <NA>  07-102-08  <NA>  420867879  2005
# 8          <NA>  07-102-08  <NA>  420867879  2005
# 9          <NA>  07-102-08  <NA>  420867879  2005
# 10         <NA>  07-102-08  <NA>  420867879  2006
# 11         <NA>  07-102-08  <NA>  420867879  2006
# 12         <NA>  07-102-08  <NA>  420867879  2006
# 13         <NA>  07-102-08  <NA>  420867879  2006
# 14         <NA>  07-102-08  <NA>  420867879  2006
# 15         <NA>  07-102-08  <NA>  420867879  2007
# 16         <NA>  07-102-08  <NA>  420867879  2007
# 17         <NA>  07-102-08  <NA>  420867879  2007
# 18         <NA>  07-102-08  <NA>  420867879  2007
# 19         <NA>  07-102-08  <NA>  420867879  2007

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Reed Valve Assemblies\MERGE\04-05mx z 600.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['SKI-DOO'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['SM-07089'], 'AD Item Number': ['121283'], 
         'Vendor Notes': [pd.NA], 'NI#': ['SM-07089'], 'REF#': [pd.NA], 'OEM#': ['420867874']}

# List of models
new_list_models = [
'Summit 600 Sport',
'Legend 600 Sport',
'Legend 600 Sport',
'MX Z 600 Sport',
'Grand Touring 600 Sport',
'MX Z 600 Sport',
'Grand Touring 600 Sport',
'GTX 600 Sport',
'GSX 600 Sport',
'Legend 600 Sport',
'GSX 600 Sport',
'GSX 600 Sport SDI'
]

oem_numbers = ['420867874']

# Range of years
years = list(range(2002, 2005))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)
# Out:
#        Make                    Model Vendor       MPN AD Item Number  \
# 0   SKI-DOO         Summit 600 Sport   NACH  SM-07089         121283
# 1   SKI-DOO         Legend 600 Sport   NACH  SM-07089         121283
# 2   SKI-DOO         Legend 600 Sport   NACH  SM-07089         121283
# 3   SKI-DOO           MX Z 600 Sport   NACH  SM-07089         121283
# 4   SKI-DOO  Grand Touring 600 Sport   NACH  SM-07089         121283
# 5   SKI-DOO           MX Z 600 Sport   NACH  SM-07089         121283
# 6   SKI-DOO  Grand Touring 600 Sport   NACH  SM-07089         121283
# 7   SKI-DOO            GTX 600 Sport   NACH  SM-07089         121283
# 8   SKI-DOO            GSX 600 Sport   NACH  SM-07089         121283
# 9   SKI-DOO         Legend 600 Sport   NACH  SM-07089         121283
# 10  SKI-DOO            GSX 600 Sport   NACH  SM-07089         121283
# 11  SKI-DOO        GSX 600 Sport SDI   NACH  SM-07089         121283
# 12  SKI-DOO         Summit 600 Sport   NACH  SM-07089         121283
# 13  SKI-DOO         Legend 600 Sport   NACH  SM-07089         121283
# 14  SKI-DOO         Legend 600 Sport   NACH  SM-07089         121283
# 15  SKI-DOO           MX Z 600 Sport   NACH  SM-07089         121283
# 16  SKI-DOO  Grand Touring 600 Sport   NACH  SM-07089         121283
# 17  SKI-DOO           MX Z 600 Sport   NACH  SM-07089         121283
# 18  SKI-DOO  Grand Touring 600 Sport   NACH  SM-07089         121283
# 19  SKI-DOO            GTX 600 Sport   NACH  SM-07089         121283
# 20  SKI-DOO            GSX 600 Sport   NACH  SM-07089         121283
# 21  SKI-DOO         Legend 600 Sport   NACH  SM-07089         121283
# 22  SKI-DOO            GSX 600 Sport   NACH  SM-07089         121283
# 23  SKI-DOO        GSX 600 Sport SDI   NACH  SM-07089         121283
# 24  SKI-DOO         Summit 600 Sport   NACH  SM-07089         121283
# 25  SKI-DOO         Legend 600 Sport   NACH  SM-07089         121283
# 26  SKI-DOO         Legend 600 Sport   NACH  SM-07089         121283
# 27  SKI-DOO           MX Z 600 Sport   NACH  SM-07089         121283
# 28  SKI-DOO  Grand Touring 600 Sport   NACH  SM-07089         121283
# 29  SKI-DOO           MX Z 600 Sport   NACH  SM-07089         121283
# 30  SKI-DOO  Grand Touring 600 Sport   NACH  SM-07089         121283
# 31  SKI-DOO            GTX 600 Sport   NACH  SM-07089         121283
# 32  SKI-DOO            GSX 600 Sport   NACH  SM-07089         121283
# 33  SKI-DOO         Legend 600 Sport   NACH  SM-07089         121283
# 34  SKI-DOO            GSX 600 Sport   NACH  SM-07089         121283
# 35  SKI-DOO        GSX 600 Sport SDI   NACH  SM-07089         121283
#
#    Vendor Notes       NI#  REF#       OEM#  Year
# 0          <NA>  SM-07089  <NA>  420867874  2002
# 1          <NA>  SM-07089  <NA>  420867874  2002
# 2          <NA>  SM-07089  <NA>  420867874  2002
# 3          <NA>  SM-07089  <NA>  420867874  2002
# 4          <NA>  SM-07089  <NA>  420867874  2002
# 5          <NA>  SM-07089  <NA>  420867874  2002
# 6          <NA>  SM-07089  <NA>  420867874  2002
# 7          <NA>  SM-07089  <NA>  420867874  2002
# 8          <NA>  SM-07089  <NA>  420867874  2002
# 9          <NA>  SM-07089  <NA>  420867874  2002
# 10         <NA>  SM-07089  <NA>  420867874  2002
# 11         <NA>  SM-07089  <NA>  420867874  2002
# 12         <NA>  SM-07089  <NA>  420867874  2003
# 13         <NA>  SM-07089  <NA>  420867874  2003
# 14         <NA>  SM-07089  <NA>  420867874  2003
# 15         <NA>  SM-07089  <NA>  420867874  2003
# 16         <NA>  SM-07089  <NA>  420867874  2003
# 17         <NA>  SM-07089  <NA>  420867874  2003
# 18         <NA>  SM-07089  <NA>  420867874  2003
# 19         <NA>  SM-07089  <NA>  420867874  2003
# 20         <NA>  SM-07089  <NA>  420867874  2003
# 21         <NA>  SM-07089  <NA>  420867874  2003
# 22         <NA>  SM-07089  <NA>  420867874  2003
# 23         <NA>  SM-07089  <NA>  420867874  2003
# 24         <NA>  SM-07089  <NA>  420867874  2004
# 25         <NA>  SM-07089  <NA>  420867874  2004
# 26         <NA>  SM-07089  <NA>  420867874  2004
# 27         <NA>  SM-07089  <NA>  420867874  2004
# 28         <NA>  SM-07089  <NA>  420867874  2004
# 29         <NA>  SM-07089  <NA>  420867874  2004
# 30         <NA>  SM-07089  <NA>  420867874  2004
# 31         <NA>  SM-07089  <NA>  420867874  2004
# 32         <NA>  SM-07089  <NA>  420867874  2004
# 33         <NA>  SM-07089  <NA>  420867874  2004
# 34         <NA>  SM-07089  <NA>  420867874  2004
# 35         <NA>  SM-07089  <NA>  420867874  2004

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Reed Valve Assemblies\MERGE\02-05SPORT 600.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['SKI-DOO'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['SM-07089'], 'AD Item Number': ['121283'], 
         'Vendor Notes': [pd.NA], 'NI#': ['SM-07089'], 'REF#': [pd.NA], 'OEM#': ['420867874']}

# List of models
new_list_models = [
'MX Z 600 Trail',
'MX Z 600 X',
'MX Z 600 Sport',
'MX Z 600 Renegade',
'MX Z 600 Adrenaline',
'Summit 600 Adrenaline'
]

oem_numbers = ['420867874']

# Range of years
years = list(range(2002, 2005))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)
# Out:
#        Make                  Model Vendor       MPN AD Item Number  \
# 0   SKI-DOO         MX Z 600 Trail   NACH  SM-07089         121283
# 1   SKI-DOO             MX Z 600 X   NACH  SM-07089         121283
# 2   SKI-DOO         MX Z 600 Sport   NACH  SM-07089         121283
# 3   SKI-DOO      MX Z 600 Renegade   NACH  SM-07089         121283
# 4   SKI-DOO    MX Z 600 Adrenaline   NACH  SM-07089         121283
# 5   SKI-DOO  Summit 600 Adrenaline   NACH  SM-07089         121283
# 6   SKI-DOO         MX Z 600 Trail   NACH  SM-07089         121283
# 7   SKI-DOO             MX Z 600 X   NACH  SM-07089         121283
# 8   SKI-DOO         MX Z 600 Sport   NACH  SM-07089         121283
# 9   SKI-DOO      MX Z 600 Renegade   NACH  SM-07089         121283
# 10  SKI-DOO    MX Z 600 Adrenaline   NACH  SM-07089         121283
# 11  SKI-DOO  Summit 600 Adrenaline   NACH  SM-07089         121283
# 12  SKI-DOO         MX Z 600 Trail   NACH  SM-07089         121283
# 13  SKI-DOO             MX Z 600 X   NACH  SM-07089         121283
# 14  SKI-DOO         MX Z 600 Sport   NACH  SM-07089         121283
# 15  SKI-DOO      MX Z 600 Renegade   NACH  SM-07089         121283
# 16  SKI-DOO    MX Z 600 Adrenaline   NACH  SM-07089         121283
# 17  SKI-DOO  Summit 600 Adrenaline   NACH  SM-07089         121283
#
#    Vendor Notes       NI#  REF#       OEM#  Year
# 0          <NA>  SM-07089  <NA>  420867874  2002
# 1          <NA>  SM-07089  <NA>  420867874  2002
# 2          <NA>  SM-07089  <NA>  420867874  2002
# 3          <NA>  SM-07089  <NA>  420867874  2002
# 4          <NA>  SM-07089  <NA>  420867874  2002
# 5          <NA>  SM-07089  <NA>  420867874  2002
# 6          <NA>  SM-07089  <NA>  420867874  2003
# 7          <NA>  SM-07089  <NA>  420867874  2003
# 8          <NA>  SM-07089  <NA>  420867874  2003
# 9          <NA>  SM-07089  <NA>  420867874  2003
# 10         <NA>  SM-07089  <NA>  420867874  2003
# 11         <NA>  SM-07089  <NA>  420867874  2003
# 12         <NA>  SM-07089  <NA>  420867874  2004
# 13         <NA>  SM-07089  <NA>  420867874  2004
# 14         <NA>  SM-07089  <NA>  420867874  2004
# 15         <NA>  SM-07089  <NA>  420867874  2004
# 16         <NA>  SM-07089  <NA>  420867874  2004
# 17         <NA>  SM-07089  <NA>  420867874  2004

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Reed Valve Assemblies\MERGE\02-05SUMMIT 600.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['LYNX'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['SM-07089'], 'AD Item Number': ['121283'], 
         'Vendor Notes': [pd.NA], 'NI#': ['SM-07089'], 'REF#': [pd.NA], 'OEM#': ['420867874']}

# List of models
new_list_models = [
'Rave RE 850 E-TEC'

]

oem_numbers = ['420867874']

# Range of years
years = list(range(2001, 2004))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)
# Out:
#    Make              Model Vendor       MPN AD Item Number Vendor Notes  \
# 0  LYNX  Rave RE 850 E-TEC   NACH  SM-07089         121283         <NA>
# 1  LYNX  Rave RE 850 E-TEC   NACH  SM-07089         121283         <NA>
# 2  LYNX  Rave RE 850 E-TEC   NACH  SM-07089         121283         <NA>
#
#         NI#  REF#       OEM#  Year
# 0  SM-07089  <NA>  420867874  2001
# 1  SM-07089  <NA>  420867874  2002
# 2  SM-07089  <NA>  420867874  2003

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Reed Valve Assemblies\MERGE\01-04LYNX.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['SKI-DOO'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['SM-07090'], 'AD Item Number': ['121283'], 
         'Vendor Notes': [pd.NA], 'NI#': ['SM-07090'], 'REF#': [pd.NA], 'OEM#': ['420867870','420867873']}

# List of models
new_list_models = [
'Legend 800 SE',
'Legend 800 SE SDI',
'MX Z 700',
'MX Z 700 Adrenaline',
'MX Z 700 Trail',
'MX Z 700 X',
'MX Z 700 Sport',
'MX Z 700 R Sport',
'MX Z 700 Renegade',
'MX Z 700 R X',
'Summit 800 R Everest',
'Summit 800 X 144',
'Summit 800 XRS 151',
'Summit 800 X',
'Summit 800 Highmark',
'Summit 800 Highmark X',
'Summit 800 Foothill',
'Summit 800',
'Summit 800 Sport',
'Summit 800 R Sport',
'Summit 800 R X',
'Summit 800 R Highmark X',
'Summit 800 R Highmark',
'Summit 800 Adrenaline 144',
'Summit 800 Highmark Xtreme',
'Summit 800 Adrenaline 151',
'Summit 800 X 163',
'Summit 800 X 154',
'Summit 800 Hill Climb',
'Summit 800 Everest 163',
'Summit 800 Everest 154',
'Summit 800 Everest 146',
'Summit 800 X 146',
'Summit 800 XRS 159',
'Summit 800 X 151',
'Summit 800 X 159',
'Summit 800 R 50th Anniversary',
'MX Z 800 Renegade',
'MX Z 800 R Adrenaline',
'MX Z 800R Renegade',
'MX Z 800R Renegade X',
'MX Z 800 Blizzard',
'MX Z 800 Renegade X',
'MX Z 800',
'MX Z 800 Adrenaline',
'MX Z 800 Trail',
'MX Z 800 X',
'MX Z 800 Sport',
'MX Z 800 R Sport',
'MX Z 800 R X',
'MX Z 800 R',
'MX Z 800 X-RS',
'Legend 700 Sport',
'Legend 700 GS',
'Legend 700 SE'
]

oem_numbers = ['420867870','420867873']

# Range of years
years = list(range(2002, 2005))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)
# Out:
#         Make                Model Vendor       MPN AD Item Number  \
# 0    SKI-DOO        Legend 800 SE   NACH  SM-07090         121283
# 1    SKI-DOO    Legend 800 SE SDI   NACH  SM-07090         121283
# 2    SKI-DOO             MX Z 700   NACH  SM-07090         121283
# 3    SKI-DOO  MX Z 700 Adrenaline   NACH  SM-07090         121283
# 4    SKI-DOO       MX Z 700 Trail   NACH  SM-07090         121283
# ..       ...                  ...    ...       ...            ...
# 325  SKI-DOO           MX Z 800 R   NACH  SM-07090         121283
# 326  SKI-DOO        MX Z 800 X-RS   NACH  SM-07090         121283
# 327  SKI-DOO     Legend 700 Sport   NACH  SM-07090         121283
# 328  SKI-DOO        Legend 700 GS   NACH  SM-07090         121283
# 329  SKI-DOO        Legend 700 SE   NACH  SM-07090         121283
#
#     Vendor Notes       NI#  REF#       OEM#  Year
# 0           <NA>  SM-07090  <NA>  420867870  2002
# 1           <NA>  SM-07090  <NA>  420867870  2002
# 2           <NA>  SM-07090  <NA>  420867870  2002
# 3           <NA>  SM-07090  <NA>  420867870  2002
# 4           <NA>  SM-07090  <NA>  420867870  2002
# ..           ...       ...   ...        ...   ...
# 325         <NA>  SM-07090  <NA>  420867873  2004
# 326         <NA>  SM-07090  <NA>  420867873  2004
# 327         <NA>  SM-07090  <NA>  420867873  2004
# 328         <NA>  SM-07090  <NA>  420867873  2004
# 329         <NA>  SM-07090  <NA>  420867873  2004
#
# [330 rows x 10 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Reed Valve Assemblies\MERGE\02-04SKIDOO.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['SKI-DOO'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['SM-07141'], 'AD Item Number': ['62-07004'], 
         'Vendor Notes': [pd.NA], 'NI#': ['SM-07141'], 'REF#': [pd.NA], 'OEM#': ['420867260']}

# List of models
new_list_models = [
'GSX 600',
'GSX 600 Limited',
'GSX 600 Sport',
'GSX 600 Sport SDI',
'MX Z 600 Sport',
'MX Z 600 R Sport',
'MX Z 600 Adrenaline',
'MX Z 600 X',
'MX Z 600 Renegade',
'MX Z 600 R X',
'MX Z 600 Trail',
'MX Z 600 Renegade X',
'MX Z 600 TNT',
'MX Z 600 X-RS',
'MX Z 600 50th Anniversary',
'MX Z 600 TNT Early Edition',
'Summit 600',
'Summit 600 R Sport',
'Summit 600 Sport',
'Summit 600 Adrenaline',
'Summit 600 X',
'Summit 600 X 154',
'Summit 600 Everest 146',
'Summit 600 Everest',
'GTX 600 Sport',
'GTX 600 Limited',
'GTX 600'

]

oem_numbers = ['420867260']

# Range of years
years = list(range(2004, 2009))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)
# Out:
#         Make                   Model Vendor       MPN AD Item Number  \
# 0    SKI-DOO                 GSX 600   NACH  SM-07141       62-07004
# 1    SKI-DOO         GSX 600 Limited   NACH  SM-07141       62-07004
# 2    SKI-DOO           GSX 600 Sport   NACH  SM-07141       62-07004
# 3    SKI-DOO       GSX 600 Sport SDI   NACH  SM-07141       62-07004
# 4    SKI-DOO          MX Z 600 Sport   NACH  SM-07141       62-07004
# ..       ...                     ...    ...       ...            ...
# 130  SKI-DOO  Summit 600 Everest 146   NACH  SM-07141       62-07004
# 131  SKI-DOO      Summit 600 Everest   NACH  SM-07141       62-07004
# 132  SKI-DOO           GTX 600 Sport   NACH  SM-07141       62-07004
# 133  SKI-DOO         GTX 600 Limited   NACH  SM-07141       62-07004
# 134  SKI-DOO                 GTX 600   NACH  SM-07141       62-07004
#
#     Vendor Notes       NI#  REF#       OEM#  Year
# 0           <NA>  SM-07141  <NA>  420867260  2004
# 1           <NA>  SM-07141  <NA>  420867260  2004
# 2           <NA>  SM-07141  <NA>  420867260  2004
# 3           <NA>  SM-07141  <NA>  420867260  2004
# 4           <NA>  SM-07141  <NA>  420867260  2004
# ..           ...       ...   ...        ...   ...
# 130         <NA>  SM-07141  <NA>  420867260  2008
# 131         <NA>  SM-07141  <NA>  420867260  2008
# 132         <NA>  SM-07141  <NA>  420867260  2008
# 133         <NA>  SM-07141  <NA>  420867260  2008
# 134         <NA>  SM-07141  <NA>  420867260  2008
#
# [135 rows x 10 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Reed Valve Assemblies\MERGE\04-09SKIDOO.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['SKI-DOO'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['SM-07180'], 'AD Item Number': ['120363'], 
         'Vendor Notes': [pd.NA], 'NI#': ['SM-07180'], 'REF#': [pd.NA], 'OEM#': ['42092451']}

# List of models
new_list_models = [
'Grand Touring LE E-TEC 600 HO'

]

oem_numbers = ['420667530']

# Range of years
years = list(range(2011, 2019))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)
# Out:
#       Make                          Model Vendor       MPN AD Item Number  \
# 0  SKI-DOO  Grand Touring LE E-TEC 600 HO   NACH  SM-07180         120363
# 1  SKI-DOO  Grand Touring LE E-TEC 600 HO   NACH  SM-07180         120363
# 2  SKI-DOO  Grand Touring LE E-TEC 600 HO   NACH  SM-07180         120363
# 3  SKI-DOO  Grand Touring LE E-TEC 600 HO   NACH  SM-07180         120363
# 4  SKI-DOO  Grand Touring LE E-TEC 600 HO   NACH  SM-07180         120363
# 5  SKI-DOO  Grand Touring LE E-TEC 600 HO   NACH  SM-07180         120363
# 6  SKI-DOO  Grand Touring LE E-TEC 600 HO   NACH  SM-07180         120363
# 7  SKI-DOO  Grand Touring LE E-TEC 600 HO   NACH  SM-07180         120363
#
#   Vendor Notes       NI#  REF#       OEM#  Year
# 0         <NA>  SM-07180  <NA>  420667530  2011
# 1         <NA>  SM-07180  <NA>  420667530  2012
# 2         <NA>  SM-07180  <NA>  420667530  2013
# 3         <NA>  SM-07180  <NA>  420667530  2014
# 4         <NA>  SM-07180  <NA>  420667530  2015
# 5         <NA>  SM-07180  <NA>  420667530  2016
# 6         <NA>  SM-07180  <NA>  420667530  2017
# 7         <NA>  SM-07180  <NA>  420667530  2018

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Reed Valve Assemblies\MERGE\11-19600HO.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['SKI-DOO'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['SM-07180'], 'AD Item Number': ['120363'], 
         'Vendor Notes': [pd.NA], 'NI#': ['SM-07180'], 'REF#': [pd.NA], 'OEM#': ['42092451']}

# List of models
new_list_models = [
'MX Z X E-TEC 600 HO',
'MX Z TNT E-TEC 600 HO',
'MX Z X-RS E-TEC 600 HO',
'MX Z Blizzard E-TEC 600 HO',
'MX Z X-RS Iron Dog E-TEC 600 HO'

]

oem_numbers = ['420667530']

# Range of years
years = list(range(2011, 2019))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)
# Out:
#        Make                            Model Vendor       MPN AD Item Number  \
# 0   SKI-DOO              MX Z X E-TEC 600 HO   NACH  SM-07180         120363
# 1   SKI-DOO            MX Z TNT E-TEC 600 HO   NACH  SM-07180         120363
# 2   SKI-DOO           MX Z X-RS E-TEC 600 HO   NACH  SM-07180         120363
# 3   SKI-DOO       MX Z Blizzard E-TEC 600 HO   NACH  SM-07180         120363
# 4   SKI-DOO  MX Z X-RS Iron Dog E-TEC 600 HO   NACH  SM-07180         120363
# 5   SKI-DOO              MX Z X E-TEC 600 HO   NACH  SM-07180         120363
# 6   SKI-DOO            MX Z TNT E-TEC 600 HO   NACH  SM-07180         120363
# 7   SKI-DOO           MX Z X-RS E-TEC 600 HO   NACH  SM-07180         120363
# 8   SKI-DOO       MX Z Blizzard E-TEC 600 HO   NACH  SM-07180         120363
# 9   SKI-DOO  MX Z X-RS Iron Dog E-TEC 600 HO   NACH  SM-07180         120363
# 10  SKI-DOO              MX Z X E-TEC 600 HO   NACH  SM-07180         120363
# 11  SKI-DOO            MX Z TNT E-TEC 600 HO   NACH  SM-07180         120363
# 12  SKI-DOO           MX Z X-RS E-TEC 600 HO   NACH  SM-07180         120363
# 13  SKI-DOO       MX Z Blizzard E-TEC 600 HO   NACH  SM-07180         120363
# 14  SKI-DOO  MX Z X-RS Iron Dog E-TEC 600 HO   NACH  SM-07180         120363
# 15  SKI-DOO              MX Z X E-TEC 600 HO   NACH  SM-07180         120363
# 16  SKI-DOO            MX Z TNT E-TEC 600 HO   NACH  SM-07180         120363
# 17  SKI-DOO           MX Z X-RS E-TEC 600 HO   NACH  SM-07180         120363
# 18  SKI-DOO       MX Z Blizzard E-TEC 600 HO   NACH  SM-07180         120363
# 19  SKI-DOO  MX Z X-RS Iron Dog E-TEC 600 HO   NACH  SM-07180         120363
# 20  SKI-DOO              MX Z X E-TEC 600 HO   NACH  SM-07180         120363
# 21  SKI-DOO            MX Z TNT E-TEC 600 HO   NACH  SM-07180         120363
# 22  SKI-DOO           MX Z X-RS E-TEC 600 HO   NACH  SM-07180         120363
# 23  SKI-DOO       MX Z Blizzard E-TEC 600 HO   NACH  SM-07180         120363
# 24  SKI-DOO  MX Z X-RS Iron Dog E-TEC 600 HO   NACH  SM-07180         120363
# 25  SKI-DOO              MX Z X E-TEC 600 HO   NACH  SM-07180         120363
# 26  SKI-DOO            MX Z TNT E-TEC 600 HO   NACH  SM-07180         120363
# 27  SKI-DOO           MX Z X-RS E-TEC 600 HO   NACH  SM-07180         120363
# 28  SKI-DOO       MX Z Blizzard E-TEC 600 HO   NACH  SM-07180         120363
# 29  SKI-DOO  MX Z X-RS Iron Dog E-TEC 600 HO   NACH  SM-07180         120363
# 30  SKI-DOO              MX Z X E-TEC 600 HO   NACH  SM-07180         120363
# 31  SKI-DOO            MX Z TNT E-TEC 600 HO   NACH  SM-07180         120363
# 32  SKI-DOO           MX Z X-RS E-TEC 600 HO   NACH  SM-07180         120363
# 33  SKI-DOO       MX Z Blizzard E-TEC 600 HO   NACH  SM-07180         120363
# 34  SKI-DOO  MX Z X-RS Iron Dog E-TEC 600 HO   NACH  SM-07180         120363
# 35  SKI-DOO              MX Z X E-TEC 600 HO   NACH  SM-07180         120363
# 36  SKI-DOO            MX Z TNT E-TEC 600 HO   NACH  SM-07180         120363
# 37  SKI-DOO           MX Z X-RS E-TEC 600 HO   NACH  SM-07180         120363
# 38  SKI-DOO       MX Z Blizzard E-TEC 600 HO   NACH  SM-07180         120363
# 39  SKI-DOO  MX Z X-RS Iron Dog E-TEC 600 HO   NACH  SM-07180         120363
#
#    Vendor Notes       NI#  REF#       OEM#  Year
# 0          <NA>  SM-07180  <NA>  420667530  2011
# 1          <NA>  SM-07180  <NA>  420667530  2011
# 2          <NA>  SM-07180  <NA>  420667530  2011
# 3          <NA>  SM-07180  <NA>  420667530  2011
# 4          <NA>  SM-07180  <NA>  420667530  2011
# 5          <NA>  SM-07180  <NA>  420667530  2012
# 6          <NA>  SM-07180  <NA>  420667530  2012
# 7          <NA>  SM-07180  <NA>  420667530  2012
# 8          <NA>  SM-07180  <NA>  420667530  2012
# 9          <NA>  SM-07180  <NA>  420667530  2012
# 10         <NA>  SM-07180  <NA>  420667530  2013
# 11         <NA>  SM-07180  <NA>  420667530  2013
# 12         <NA>  SM-07180  <NA>  420667530  2013
# 13         <NA>  SM-07180  <NA>  420667530  2013
# 14         <NA>  SM-07180  <NA>  420667530  2013
# 15         <NA>  SM-07180  <NA>  420667530  2014
# 16         <NA>  SM-07180  <NA>  420667530  2014
# 17         <NA>  SM-07180  <NA>  420667530  2014
# 18         <NA>  SM-07180  <NA>  420667530  2014
# 19         <NA>  SM-07180  <NA>  420667530  2014
# 20         <NA>  SM-07180  <NA>  420667530  2015
# 21         <NA>  SM-07180  <NA>  420667530  2015
# 22         <NA>  SM-07180  <NA>  420667530  2015
# 23         <NA>  SM-07180  <NA>  420667530  2015
# 24         <NA>  SM-07180  <NA>  420667530  2015
# 25         <NA>  SM-07180  <NA>  420667530  2016
# 26         <NA>  SM-07180  <NA>  420667530  2016
# 27         <NA>  SM-07180  <NA>  420667530  2016
# 28         <NA>  SM-07180  <NA>  420667530  2016
# 29         <NA>  SM-07180  <NA>  420667530  2016
# 30         <NA>  SM-07180  <NA>  420667530  2017
# 31         <NA>  SM-07180  <NA>  420667530  2017
# 32         <NA>  SM-07180  <NA>  420667530  2017
# 33         <NA>  SM-07180  <NA>  420667530  2017
# 34         <NA>  SM-07180  <NA>  420667530  2017
# 35         <NA>  SM-07180  <NA>  420667530  2018
# 36         <NA>  SM-07180  <NA>  420667530  2018
# 37         <NA>  SM-07180  <NA>  420667530  2018
# 38         <NA>  SM-07180  <NA>  420667530  2018
# 39         <NA>  SM-07180  <NA>  420667530  2018

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Reed Valve Assemblies\MERGE\11-19mxz.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['SKI-DOO'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['SM-07180'], 'AD Item Number': ['120363'], 
         'Vendor Notes': [pd.NA], 'NI#': ['SM-07180'], 'REF#': [pd.NA], 'OEM#': ['42092451']}

# List of models
new_list_models = [
    
'Renegade Backcountry X E-TEC 600 HO',
'Expedition 600 SE',
'Grand Touring 600 LE',
'Expedition LE E-TEC 600 HO',
'Expedition SE E-TEC 600 HO'

]

oem_numbers = ['420667530']

# Range of years
years = list(range(2011, 2019))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)
# Out:
#        Make                                Model Vendor       MPN  \
# 0   SKI-DOO  Renegade Backcountry X E-TEC 600 HO   NACH  SM-07180
# 1   SKI-DOO                    Expedition 600 SE   NACH  SM-07180
# 2   SKI-DOO                 Grand Touring 600 LE   NACH  SM-07180
# 3   SKI-DOO           Expedition LE E-TEC 600 HO   NACH  SM-07180
# 4   SKI-DOO           Expedition SE E-TEC 600 HO   NACH  SM-07180
# 5   SKI-DOO  Renegade Backcountry X E-TEC 600 HO   NACH  SM-07180
# 6   SKI-DOO                    Expedition 600 SE   NACH  SM-07180
# 7   SKI-DOO                 Grand Touring 600 LE   NACH  SM-07180
# 8   SKI-DOO           Expedition LE E-TEC 600 HO   NACH  SM-07180
# 9   SKI-DOO           Expedition SE E-TEC 600 HO   NACH  SM-07180
# 10  SKI-DOO  Renegade Backcountry X E-TEC 600 HO   NACH  SM-07180
# 11  SKI-DOO                    Expedition 600 SE   NACH  SM-07180
# 12  SKI-DOO                 Grand Touring 600 LE   NACH  SM-07180
# 13  SKI-DOO           Expedition LE E-TEC 600 HO   NACH  SM-07180
# 14  SKI-DOO           Expedition SE E-TEC 600 HO   NACH  SM-07180
# 15  SKI-DOO  Renegade Backcountry X E-TEC 600 HO   NACH  SM-07180
# 16  SKI-DOO                    Expedition 600 SE   NACH  SM-07180
# 17  SKI-DOO                 Grand Touring 600 LE   NACH  SM-07180
# 18  SKI-DOO           Expedition LE E-TEC 600 HO   NACH  SM-07180
# 19  SKI-DOO           Expedition SE E-TEC 600 HO   NACH  SM-07180
# 20  SKI-DOO  Renegade Backcountry X E-TEC 600 HO   NACH  SM-07180
# 21  SKI-DOO                    Expedition 600 SE   NACH  SM-07180
# 22  SKI-DOO                 Grand Touring 600 LE   NACH  SM-07180
# 23  SKI-DOO           Expedition LE E-TEC 600 HO   NACH  SM-07180
# 24  SKI-DOO           Expedition SE E-TEC 600 HO   NACH  SM-07180
# 25  SKI-DOO  Renegade Backcountry X E-TEC 600 HO   NACH  SM-07180
# 26  SKI-DOO                    Expedition 600 SE   NACH  SM-07180
# 27  SKI-DOO                 Grand Touring 600 LE   NACH  SM-07180
# 28  SKI-DOO           Expedition LE E-TEC 600 HO   NACH  SM-07180
# 29  SKI-DOO           Expedition SE E-TEC 600 HO   NACH  SM-07180
# 30  SKI-DOO  Renegade Backcountry X E-TEC 600 HO   NACH  SM-07180
# 31  SKI-DOO                    Expedition 600 SE   NACH  SM-07180
# 32  SKI-DOO                 Grand Touring 600 LE   NACH  SM-07180
# 33  SKI-DOO           Expedition LE E-TEC 600 HO   NACH  SM-07180
# 34  SKI-DOO           Expedition SE E-TEC 600 HO   NACH  SM-07180
# 35  SKI-DOO  Renegade Backcountry X E-TEC 600 HO   NACH  SM-07180
# 36  SKI-DOO                    Expedition 600 SE   NACH  SM-07180
# 37  SKI-DOO                 Grand Touring 600 LE   NACH  SM-07180
# 38  SKI-DOO           Expedition LE E-TEC 600 HO   NACH  SM-07180
# 39  SKI-DOO           Expedition SE E-TEC 600 HO   NACH  SM-07180
#
#    AD Item Number Vendor Notes       NI#  REF#       OEM#  Year
# 0          120363         <NA>  SM-07180  <NA>  420667530  2011
# 1          120363         <NA>  SM-07180  <NA>  420667530  2011
# 2          120363         <NA>  SM-07180  <NA>  420667530  2011
# 3          120363         <NA>  SM-07180  <NA>  420667530  2011
# 4          120363         <NA>  SM-07180  <NA>  420667530  2011
# 5          120363         <NA>  SM-07180  <NA>  420667530  2012
# 6          120363         <NA>  SM-07180  <NA>  420667530  2012
# 7          120363         <NA>  SM-07180  <NA>  420667530  2012
# 8          120363         <NA>  SM-07180  <NA>  420667530  2012
# 9          120363         <NA>  SM-07180  <NA>  420667530  2012
# 10         120363         <NA>  SM-07180  <NA>  420667530  2013
# 11         120363         <NA>  SM-07180  <NA>  420667530  2013
# 12         120363         <NA>  SM-07180  <NA>  420667530  2013
# 13         120363         <NA>  SM-07180  <NA>  420667530  2013
# 14         120363         <NA>  SM-07180  <NA>  420667530  2013
# 15         120363         <NA>  SM-07180  <NA>  420667530  2014
# 16         120363         <NA>  SM-07180  <NA>  420667530  2014
# 17         120363         <NA>  SM-07180  <NA>  420667530  2014
# 18         120363         <NA>  SM-07180  <NA>  420667530  2014
# 19         120363         <NA>  SM-07180  <NA>  420667530  2014
# 20         120363         <NA>  SM-07180  <NA>  420667530  2015
# 21         120363         <NA>  SM-07180  <NA>  420667530  2015
# 22         120363         <NA>  SM-07180  <NA>  420667530  2015
# 23         120363         <NA>  SM-07180  <NA>  420667530  2015
# 24         120363         <NA>  SM-07180  <NA>  420667530  2015
# 25         120363         <NA>  SM-07180  <NA>  420667530  2016
# 26         120363         <NA>  SM-07180  <NA>  420667530  2016
# 27         120363         <NA>  SM-07180  <NA>  420667530  2016
# 28         120363         <NA>  SM-07180  <NA>  420667530  2016
# 29         120363         <NA>  SM-07180  <NA>  420667530  2016
# 30         120363         <NA>  SM-07180  <NA>  420667530  2017
# 31         120363         <NA>  SM-07180  <NA>  420667530  2017
# 32         120363         <NA>  SM-07180  <NA>  420667530  2017
# 33         120363         <NA>  SM-07180  <NA>  420667530  2017
# 34         120363         <NA>  SM-07180  <NA>  420667530  2017
# 35         120363         <NA>  SM-07180  <NA>  420667530  2018
# 36         120363         <NA>  SM-07180  <NA>  420667530  2018
# 37         120363         <NA>  SM-07180  <NA>  420667530  2018
# 38         120363         <NA>  SM-07180  <NA>  420667530  2018
# 39         120363         <NA>  SM-07180  <NA>  420667530  2018

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Reed Valve Assemblies\MERGE\11-19exprenemxgrand.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['SKI-DOO'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['SM-07180'], 'AD Item Number': ['120363'], 
         'Vendor Notes': [pd.NA], 'NI#': ['SM-07180'], 'REF#': [pd.NA], 'OEM#': ['42092451']}

# List of models
new_list_models = [
    
'Skandic 600 WT',
'Skandic WT E-TEC 600 HO',
'Skandic SWT ACE 600',
'Tundra Xtreme E-TEC 600 HO',
'Summit SP E-TEC 600 HO 154',
'Summit SP E-TEC 600 HO 146',
'Grand Touring LE E-TEC 600 HO',
'MX Z X-RS E-TEC 600 HO',
'MX Z X E-TEC 600 HO',
'MX Z TNT E-TEC 600 HO',
'MX Z Blizzard E-TEC 600 HO',
'Renegade 600 X',
'Renegade Backcountry X E-TEC 600 HO',
'Renegade X E-TEC 600 HO',
'Renegade Backcountry E-TEC 600 HO',
'Renegade Adrenaline E-TEC 600 HO',
'Renegade Enduro E-TEC 600 HO',
'Expedition SE E-TEC 600 HO',
'Expedition LE E-TEC 600 HO',
'Tundra Sport ACE 600'

]

oem_numbers = ['420667530']

# Range of years
years = list(range(2011, 2022))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)
# Out:
#         Make                             Model Vendor       MPN  \
# 0    SKI-DOO                    Skandic 600 WT   NACH  SM-07180
# 1    SKI-DOO           Skandic WT E-TEC 600 HO   NACH  SM-07180
# 2    SKI-DOO               Skandic SWT ACE 600   NACH  SM-07180
# 3    SKI-DOO        Tundra Xtreme E-TEC 600 HO   NACH  SM-07180
# 4    SKI-DOO        Summit SP E-TEC 600 HO 154   NACH  SM-07180
# ..       ...                               ...    ...       ...
# 215  SKI-DOO  Renegade Adrenaline E-TEC 600 HO   NACH  SM-07180
# 216  SKI-DOO      Renegade Enduro E-TEC 600 HO   NACH  SM-07180
# 217  SKI-DOO        Expedition SE E-TEC 600 HO   NACH  SM-07180
# 218  SKI-DOO        Expedition LE E-TEC 600 HO   NACH  SM-07180
# 219  SKI-DOO              Tundra Sport ACE 600   NACH  SM-07180
#
#     AD Item Number Vendor Notes       NI#  REF#       OEM#  Year
# 0           120363         <NA>  SM-07180  <NA>  420667530  2011
# 1           120363         <NA>  SM-07180  <NA>  420667530  2011
# 2           120363         <NA>  SM-07180  <NA>  420667530  2011
# 3           120363         <NA>  SM-07180  <NA>  420667530  2011
# 4           120363         <NA>  SM-07180  <NA>  420667530  2011
# ..             ...          ...       ...   ...        ...   ...
# 215         120363         <NA>  SM-07180  <NA>  420667530  2021
# 216         120363         <NA>  SM-07180  <NA>  420667530  2021
# 217         120363         <NA>  SM-07180  <NA>  420667530  2021
# 218         120363         <NA>  SM-07180  <NA>  420667530  2021
# 219         120363         <NA>  SM-07180  <NA>  420667530  2021
#
# [220 rows x 10 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Reed Valve Assemblies\MERGE\11-22tundraexpidrene.csv"
final_df.to_csv(file_path, index=False)
